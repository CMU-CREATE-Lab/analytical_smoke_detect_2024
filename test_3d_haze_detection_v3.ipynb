# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import HTML
from haze_detection_3d import *
from common import *
from imaging import *
from thumbnail_api import Thumbnail

def show_images(vid):
	fig = plt.figure(figsize=(32, 32))
    
	for i in range(len(vid)):
		sub = fig.add_subplot(4, len(vid) // 4, i + 1)
		sub.imshow(vid[i] * 255.0)

# %%
url_no_smoke = "https://thumbnails-v2.createlab.org/thumbnail?root=https%3A%2F%2Fbreathecam.org%2F%23v%3D4616%2C2053%2C1.99%2Cpts%26t%3D1015.36%26ps%3D0%26bt%3D20240519140924%26et%3D20240519140924%26startDwell%3D0%26endDwell%3D0%26d%3D2024-05-19%26s%3Dclairton4%26fps%3D9&width=400&height=300&format=png&fps=9&tileFormat=mp4&startDwell=0&endDwell=0&fromScreenshot&minimalUI"

url_with_smoke = "https://thumbnails-v2.createlab.org/thumbnail?root=https%3A%2F%2Fbreathecam.org%2F%23v%3D4616%2C2053%2C1.99%2Cpts%26t%3D983.02%26ps%3D0%26bt%3D20240519135000%26et%3D20240519135000%26startDwell%3D0%26endDwell%3D0%26d%3D2024-05-19%26s%3Dclairton4%26fps%3D9&width=400&height=300&format=png&fps=9&tileFormat=mp4&startDwell=0&endDwell=0&fromScreenshot&minimalUI"

# %%
def low_resolution_3d_haze_detection(url, *, subsample, solver):
    bg = read_image_from_url(url_no_smoke, subsample=subsample) / 255.0

    vid1 = stack_n_frames(url, subsample=subsample, count=40)
    vid0 = np.array([bg] * vid1.shape[0])

    return vid0, vid1, solver(vid0, vid1)

# %%
v_no_smoke, v_with_smoke, v_detection = low_resolution_3d_haze_detection(url_with_smoke, subsample=8, solver=solve_3d_haze_detection_v1)
len(v_no_smoke), len(v_with_smoke), len(v_detection)
# Out:
# solve_3d_haze_detection_v1 50x32x40, 64000 pixels: solve_3d_haze_detection_v1 50x32x40, 64000 pixels: 3039.6 seconds, 194307.2 seconds CPU
# (40, 40, 40)

# %%
fig, ax = plt.subplots()

ims = []

for i in range(len(v_no_smoke)):
   ims.append([ax.imshow(v_no_smoke[i] * 255.0, animated=True)])

anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=1000)

plt.close()

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
fig, ax = plt.subplots()

ims = []

for i in range(len(v_with_smoke)):
   ims.append([ax.imshow(v_with_smoke[i] * 255.0, animated=True)])

anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=1000)

plt.close()

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
fig, ax = plt.subplots()

ims = []

for i in range(len(v_detection)):
   ims.append([ax.imshow(v_detection[i] * 255.0, animated=True)])

anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=1000)

plt.close()

HTML(anim.to_jshtml())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.1333756220995177e-12..254.99999999999787].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.0697098130132433e-12..254.99999999999793].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [3.59619201509581e-21..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [3.877257673257171e-18..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [4.14731658185011e-27..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [3.719927192247269e-18..254.99999999999804].
# ...
